# %% [markdown]
# <a href="https://www.kaggle.com/marcuscheong/pawpularity-contest?scriptVersionId=88448317" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
from tqdm import tqdm

import pandas as pd
import numpy as np
import imagehash
from PIL import Image

# import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit

import tensorflow as tf
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Input, Concatenate, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.models import load_model

gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

import cv2


def getImagePath(imgId, dataType):
    if dataType == 'train':
        return os.path.join("../input/petfinder-pawpularity-score/train", imgId+'.jpg')
    if dataType == 'test':
        return os.path.join("../input/petfinder-pawpularity-score/test", imgId+'.jpg')
# Out:
# 2022-02-22 07:07:29.699433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:07:29.814930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:07:29.815783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
# from keras_tuner.tuners import RandomSearch
# from keras_tuner.engine.hyperparameters import HyperParameters
# from keras_tuner import Objective
# import time

# LOG_DIR = f"{int(time.time())}"

# %%
trainCSV = pd.read_csv("../input/petfinder-pawpularity-score/train.csv")
testCSV = pd.read_csv("../input/petfinder-pawpularity-score/test.csv")

trainImgDir = "../input/petfinder-pawpularity-score/train"
simImgDict = {}
rowsToRemove = []
for imgName in tqdm(os.listdir(trainImgDir)):
    hash = imagehash.phash(Image.open(os.path.join(trainImgDir, imgName)))
    if hash not in simImgDict:
        simImgDict[hash] = [imgName, []]
    else:
        simImgDict[hash][1].append(imgName)

print("Len of train images before deduplication: {}".format(len(trainCSV)))
for k,v in simImgDict.items():
    if(len(v[1])>0):
        for imgPath in v[1]:
            trainCSV.drop(trainCSV.index[trainCSV["Id"] == imgPath[:-4]], inplace=True)
            
del simImgDict
print("Len of train images after deduplication: {}".format(len(trainCSV)))
trainCSV.reset_index(drop=True, inplace=True)

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25, random_state=42)
for train_index, val_index in split.split(trainCSV, trainCSV['Pawpularity']):
    trainDF = trainCSV.loc[train_index]
    valDF = trainCSV.loc[val_index]


del trainCSV
del split
# Out:
# 100%|██████████| 9912/9912 [04:00<00:00, 41.15it/s]
# Len of train images before deduplication: 9912
# Len of train images after deduplication: 9890

# %%
trainX = trainDF.drop("Pawpularity", axis=1)
trainY = trainDF.Pawpularity
valX = valDF.drop("Pawpularity", axis=1)
valY = valDF.Pawpularity

imgTrainXList = []
imgValXList = []
imgTestXList = []

IMG_SIZE = 64

for imgId in tqdm(trainX.Id):
    imgTrainXList.append(cv2.cvtColor(cv2.resize(cv2.imread(getImagePath(imgId,'train')), (IMG_SIZE, IMG_SIZE)), cv2.COLOR_BGR2RGB)/255.)

imgTrainX =  np.array(imgTrainXList).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
featuresTrainX = trainX.drop('Id', axis=1)
del imgTrainXList
del trainX
del trainDF

for imgId in tqdm(valX.Id):
    imgValXList.append(cv2.cvtColor(cv2.resize(cv2.imread(getImagePath(imgId,'train')), (IMG_SIZE, IMG_SIZE)), cv2.COLOR_BGR2RGB)/255.)
    
imgValX = np.array(imgValXList).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
featuresValX = valX.drop('Id', axis=1)
del imgValXList
del valX
del valDF
    

for imgId in tqdm(testCSV.Id):
    imgTestXList.append(cv2.cvtColor(cv2.resize(cv2.imread(getImagePath(imgId,'test')), (IMG_SIZE, IMG_SIZE)), cv2.COLOR_BGR2RGB)/255.)

imgTestX = np.array(imgTestXList).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
del imgTestXList

featuresTestX = testCSV.drop('Id', axis=1)
# Out:
# 100%|██████████| 7417/7417 [01:10<00:00, 104.81it/s]
# 100%|██████████| 2473/2473 [00:23<00:00, 105.37it/s]
# 100%|██████████| 8/8 [00:00<00:00, 138.54it/s]

# %%
# def buildModel(hp):
#     img_input = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
#     imgModel = Conv2D(hp.Int("img_input_units", min_value=32, max_value=256, step=32), kernel_size=(3, 3), activation='relu', input_shape=(IMG_SIZE,IMG_SIZE,3))(img_input)
    
#     for i in range(hp.Int("img_n_layers", 1, 4)):
#         imgModel = Conv2D(hp.Int("conv_{}_units".format(i), min_value=32, max_value=256, step=32), (3, 3), activation='relu')(imgModel)
#         imgModel = MaxPooling2D(pool_size=(2, 2))(imgModel)
#         imgModel = Dropout(rate=hp.Float("dropout_{}_rate".format(i), 0, 0.5, step=0.1))(imgModel)

#     imgModel = GlobalAveragePooling2D()(imgModel)
#     imgModel = Dense(128, activation='relu')(imgModel)
#     imgModel = Dropout(0.5)(imgModel)
#     imgModelOutput = Dense(1, activation='linear')(imgModel)

#     tag_input = Input(shape = featuresTrainX.shape[1:])
#     tagModel = Dense(hp.Int("features_input_units", min_value=32, max_value=256, step=32), input_dim=12, activation='relu')(tag_input)
#     for i in range(hp.Int("features_n_layers", 1, 4)):
#         tagModel = Dense(hp.Int("feature_dense_{}_units".format(i), min_value=32, max_value=256, step=32))(tagModel)
    
#     tagModelOutput = Dense(1, activation='linear')(tagModel)

#     concatenated = Concatenate(axis=-1)([imgModelOutput, tagModelOutput])
#     concatModel = Flatten()(concatenated)
#     for i in range(hp.Int("concat_n_layers",1, 4)):
#         concatModel = Dense(hp.Int("concat_dense_{}_units".format(i), min_value=32, max_value=64, step=16))(concatModel)
#     output = Dense(1, activation='linear')(concatModel)

#     model = Model([img_input, tag_input], output)
#     # model.summary()

#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
#     return model

# tuner = RandomSearch(
#     buildModel,
#     objective = Objective("val_root_mean_squared_error", direction="min"),
#     max_trials = 30,
#     executions_per_trial = 1,
#     directory = LOG_DIR
# )


# earlyStopping = tf.keras.callbacks.EarlyStopping(
#     monitor='val_root_mean_squared_error', min_delta=0, patience=15, verbose=0,
#     mode='auto', baseline=None, restore_best_weights=True
# )


# tuner.search(x=[imgTrainX, featuresTrainX], 
#              y=trainY,
#             epochs = 40,
#             batch_size = 64,
#             validation_data = ((imgValX, featuresValX), valY),
#             callbacks=[earlyStopping],
#             verbose=1
#             )

# tuner.results_summary()

# Results summary
# Results in D:\Kaggle\pawpularity\keras_tuner_log\1642147429\untitled_project
# Showing 10 best trials
# Objective(name='val_root_mean_squared_error', direction='min')

# Trial summary
# Hyperparameters:
# img_input_units: 32
# img_n_layers: 4
# conv_0_units: 96
# dropout_0_rate: 0.5
# features_input_units: 128
# features_n_layers: 2
# feature_dense_0_units: 192
# concat_n_layers: 3
# concat_dense_0_units: 48
# learning_rate: 0.0001
# conv_1_units: 192
# dropout_1_rate: 0.1
# feature_dense_1_units: 32
# feature_dense_2_units: 192
# concat_dense_1_units: 48
# concat_dense_2_units: 48
# conv_2_units: 224
# dropout_2_rate: 0.1
# concat_dense_3_units: 48
# conv_3_units: 32
# dropout_3_rate: 0.0
# Score: 20.45026206970215

# %%
img_input = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
imgModel = Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(IMG_SIZE,IMG_SIZE,3))(img_input)

imgModel = Conv2D(96, (3, 3), activation='relu')(imgModel)
imgModel = MaxPooling2D(pool_size=(2, 2))(imgModel)
imgModel = Dropout(0.5)(imgModel)

imgModel = Conv2D(192, (3, 3), activation='relu')(imgModel)
imgModel = MaxPooling2D(pool_size=(2, 2))(imgModel)
imgModel = Dropout(0.1)(imgModel)

imgModel = Conv2D(224, (3, 3), activation='relu')(imgModel)
imgModel = MaxPooling2D(pool_size=(2, 2))(imgModel)
imgModel = Dropout(0.1)(imgModel)

imgModel = Conv2D(32, (3, 3), activation='relu')(imgModel)
imgModel = MaxPooling2D(pool_size=(2, 2))(imgModel)
imgModel = Dropout(0)(imgModel)

imgModel = GlobalAveragePooling2D()(imgModel)
imgModel = Dense(128, activation='relu')(imgModel)
imgModel = Dropout(0.5)(imgModel)
imgModelOutput = Dense(1, activation='linear')(imgModel)

tag_input = Input(shape = featuresTrainX.shape[1:])
tagModel = Dense(128, input_dim=12, activation='relu')(tag_input)
tagModel = Dense(192, activation='relu')(tagModel)
tagModel = Dense(32, activation='relu')(tagModel)
tagModel = Dense(192, activation='relu')(tagModel)
tagModelOutput = Dense(1, activation='linear')(tagModel)

concatenated = Concatenate(axis=-1)([imgModelOutput, tagModelOutput])
concatModel = Flatten()(concatenated)
concatModel = Dense(48, activation='relu')(concatenated)
concatModel = Dense(48, activation='relu')(concatenated)
concatModel = Dense(48, activation='relu')(concatenated)
concatModel = Dense(48, activation='relu')(concatenated)
output = Dense(1, activation='linear')(concatModel)

model = Model([img_input, tag_input], output)
model.summary()

earlyStopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_root_mean_squared_error', min_delta=0, patience=15, verbose=0,
    mode='auto', baseline=None, restore_best_weights=True
)


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])


model.fit(x=[imgTrainX, featuresTrainX], 
             y=trainY,
            epochs = 40,
            batch_size = 64,
            validation_data = ((imgValX, featuresValX), valY),
            callbacks=[earlyStopping],
            verbose=1
            )
# Out:
# 2022-02-22 07:13:10.602148: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-22 07:13:10.603554: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:10.604339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:10.604946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:12.226964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:12.227790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:12.228431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-22 07:13:12.229026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 62, 62, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 60, 96)   27744       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 30, 30, 96)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 30, 96)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 192)  166080      dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 14, 14, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 224)  387296      dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 224)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 6, 6, 224)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 32)     64544       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 32)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 12)]         0
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2, 2, 32)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1664        input_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 192)          24768       dense_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          4224        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           6176        dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 192)          6336        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            193         dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           dense_1[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 48)           144         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            49          dense_10[0][0]
# ==================================================================================================
# Total params: 690,243
# Trainable params: 690,243
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-02-22 07:13:13.262263: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/40
# 2022-02-22 07:13:15.776849: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 116/116 [==============================] - 11s 30ms/step - loss: 954.3840 - root_mean_squared_error: 30.8931 - val_loss: 527.0646 - val_root_mean_squared_error: 22.9579
# Epoch 2/40
# 116/116 [==============================] - 3s 24ms/step - loss: 509.6398 - root_mean_squared_error: 22.5752 - val_loss: 520.0698 - val_root_mean_squared_error: 22.8050
# Epoch 3/40
# 116/116 [==============================] - 3s 22ms/step - loss: 491.4761 - root_mean_squared_error: 22.1693 - val_loss: 542.8448 - val_root_mean_squared_error: 23.2990
# Epoch 4/40
# 116/116 [==============================] - 3s 23ms/step - loss: 484.0817 - root_mean_squared_error: 22.0019 - val_loss: 482.3124 - val_root_mean_squared_error: 21.9616
# Epoch 5/40
# 116/116 [==============================] - 3s 22ms/step - loss: 470.3371 - root_mean_squared_error: 21.6873 - val_loss: 475.8808 - val_root_mean_squared_error: 21.8147
# Epoch 6/40
# 116/116 [==============================] - 3s 22ms/step - loss: 460.5753 - root_mean_squared_error: 21.4610 - val_loss: 477.1862 - val_root_mean_squared_error: 21.8446
# Epoch 7/40
# 116/116 [==============================] - 3s 23ms/step - loss: 459.2711 - root_mean_squared_error: 21.4306 - val_loss: 449.7564 - val_root_mean_squared_error: 21.2075
# Epoch 8/40
# 116/116 [==============================] - 3s 25ms/step - loss: 452.0694 - root_mean_squared_error: 21.2619 - val_loss: 478.6071 - val_root_mean_squared_error: 21.8771
# Epoch 9/40
# 116/116 [==============================] - 3s 22ms/step - loss: 446.3399 - root_mean_squared_error: 21.1268 - val_loss: 442.0549 - val_root_mean_squared_error: 21.0251
# Epoch 10/40
# 116/116 [==============================] - 3s 22ms/step - loss: 443.1540 - root_mean_squared_error: 21.0512 - val_loss: 440.3213 - val_root_mean_squared_error: 20.9838
# Epoch 11/40
# 116/116 [==============================] - 3s 22ms/step - loss: 440.9930 - root_mean_squared_error: 20.9998 - val_loss: 446.6923 - val_root_mean_squared_error: 21.1351
# Epoch 12/40
# 116/116 [==============================] - 3s 23ms/step - loss: 438.4935 - root_mean_squared_error: 20.9402 - val_loss: 438.4315 - val_root_mean_squared_error: 20.9388
# Epoch 13/40
# 116/116 [==============================] - 3s 22ms/step - loss: 437.2414 - root_mean_squared_error: 20.9103 - val_loss: 429.8927 - val_root_mean_squared_error: 20.7339
# Epoch 14/40
# 116/116 [==============================] - 3s 23ms/step - loss: 435.0562 - root_mean_squared_error: 20.8580 - val_loss: 437.6076 - val_root_mean_squared_error: 20.9191
# Epoch 15/40
# 116/116 [==============================] - 3s 23ms/step - loss: 432.3094 - root_mean_squared_error: 20.7920 - val_loss: 427.7972 - val_root_mean_squared_error: 20.6833
# Epoch 16/40
# 116/116 [==============================] - 3s 23ms/step - loss: 430.6381 - root_mean_squared_error: 20.7518 - val_loss: 425.0939 - val_root_mean_squared_error: 20.6178
# Epoch 17/40
# 116/116 [==============================] - 3s 22ms/step - loss: 429.8523 - root_mean_squared_error: 20.7329 - val_loss: 421.2696 - val_root_mean_squared_error: 20.5249
# Epoch 18/40
# 116/116 [==============================] - 3s 22ms/step - loss: 427.9959 - root_mean_squared_error: 20.6881 - val_loss: 421.9957 - val_root_mean_squared_error: 20.5425
# Epoch 19/40
# 116/116 [==============================] - 3s 22ms/step - loss: 426.9821 - root_mean_squared_error: 20.6635 - val_loss: 419.2478 - val_root_mean_squared_error: 20.4755
# Epoch 20/40
# 116/116 [==============================] - 3s 24ms/step - loss: 426.3571 - root_mean_squared_error: 20.6484 - val_loss: 421.6409 - val_root_mean_squared_error: 20.5339
# Epoch 21/40
# 116/116 [==============================] - 3s 22ms/step - loss: 425.4527 - root_mean_squared_error: 20.6265 - val_loss: 421.8749 - val_root_mean_squared_error: 20.5396
# Epoch 22/40
# 116/116 [==============================] - 3s 22ms/step - loss: 424.2769 - root_mean_squared_error: 20.5980 - val_loss: 419.8062 - val_root_mean_squared_error: 20.4892
# Epoch 23/40
# 116/116 [==============================] - 3s 22ms/step - loss: 424.9212 - root_mean_squared_error: 20.6136 - val_loss: 418.6225 - val_root_mean_squared_error: 20.4603
# Epoch 24/40
# 116/116 [==============================] - 3s 23ms/step - loss: 424.3884 - root_mean_squared_error: 20.6007 - val_loss: 419.7524 - val_root_mean_squared_error: 20.4879
# Epoch 25/40
# 116/116 [==============================] - 3s 23ms/step - loss: 424.6464 - root_mean_squared_error: 20.6070 - val_loss: 419.7096 - val_root_mean_squared_error: 20.4868
# Epoch 26/40
# 116/116 [==============================] - 3s 22ms/step - loss: 424.0062 - root_mean_squared_error: 20.5914 - val_loss: 419.9167 - val_root_mean_squared_error: 20.4919
# Epoch 27/40
# 116/116 [==============================] - 3s 23ms/step - loss: 423.5650 - root_mean_squared_error: 20.5807 - val_loss: 419.4807 - val_root_mean_squared_error: 20.4812
# Epoch 28/40
# 116/116 [==============================] - 3s 23ms/step - loss: 423.7848 - root_mean_squared_error: 20.5860 - val_loss: 421.0180 - val_root_mean_squared_error: 20.5187
# Epoch 29/40
# 116/116 [==============================] - 3s 24ms/step - loss: 423.4000 - root_mean_squared_error: 20.5767 - val_loss: 422.3885 - val_root_mean_squared_error: 20.5521
# Epoch 30/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.7489 - root_mean_squared_error: 20.5609 - val_loss: 419.4787 - val_root_mean_squared_error: 20.4812
# Epoch 31/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.8683 - root_mean_squared_error: 20.5638 - val_loss: 424.5938 - val_root_mean_squared_error: 20.6057
# Epoch 32/40
# 116/116 [==============================] - 3s 23ms/step - loss: 422.3853 - root_mean_squared_error: 20.5520 - val_loss: 419.5726 - val_root_mean_squared_error: 20.4835
# Epoch 33/40
# 116/116 [==============================] - 3s 23ms/step - loss: 422.7210 - root_mean_squared_error: 20.5602 - val_loss: 421.1544 - val_root_mean_squared_error: 20.5220
# Epoch 34/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.6646 - root_mean_squared_error: 20.5588 - val_loss: 419.9114 - val_root_mean_squared_error: 20.4917
# Epoch 35/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.4616 - root_mean_squared_error: 20.5539 - val_loss: 421.1304 - val_root_mean_squared_error: 20.5215
# Epoch 36/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.2649 - root_mean_squared_error: 20.5491 - val_loss: 420.8684 - val_root_mean_squared_error: 20.5151
# Epoch 37/40
# 116/116 [==============================] - 3s 23ms/step - loss: 422.6120 - root_mean_squared_error: 20.5575 - val_loss: 419.2766 - val_root_mean_squared_error: 20.4762
# Epoch 38/40
# 116/116 [==============================] - 3s 22ms/step - loss: 422.8253 - root_mean_squared_error: 20.5627 - val_loss: 419.5355 - val_root_mean_squared_error: 20.4826

# %%
# imgModel.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
# imgModel.fit(imgTrainX, trainY,
#     validation_data=((imgValX, valY), epochs=30, batch_size=32, callbacks=[earlyStopping])

# %%
# model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
# model.fit([imgTrainX, featuresTrainX], trainY,
#     validation_data=((imgValX, featuresValX), valY), epochs=30, batch_size=32, callbacks=[earlyStopping])

# %%
testPred = model.predict([imgTestX, featuresTestX])
testPred
# Out:
# array([[36.06995 ],
#        [35.058712],
#        [38.25648 ],
#        [30.933191],
#        [31.586992],
#        [41.114   ],
#        [28.85461 ],
#        [33.188602]], dtype=float32)

# %%
submissionData = []

for id, pawScore in zip(testCSV.Id, testPred):
    submissionData.append([id, pawScore[0]])
submissionDF = pd.DataFrame(submissionData, columns=['Id', 'Pawpularity']) 
submissionDF
submissionDF.to_csv('submission.csv',index=False)
